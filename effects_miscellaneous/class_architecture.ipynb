# %%
# Base class in QSP
class Effect:
    def __init__(self, params):
        self.params = params

    def apply(self, signal):
        raise NotImplementedError


# QSP Effects
class DelayLine(Effect):
    def apply(self, signal):
        # delay line circuit
        return processed_signal


class TimeReversal(Effect):
    def apply(self, signal):
        # time reversal circuit
        return processed_signal

...


a = processed_signal = DelayLine(params).apply(input_signal)
